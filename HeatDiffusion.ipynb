# %% [markdown]
# <a href="https://colab.research.google.com/github/chetools/CHE4071_Spring2026/blob/main/HeatDiffusion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -N -q https://raw.githubusercontent.com/chetools/chetools/main/tools/che5.ipynb -O che5.ipynb
# %run che5.ipynb

# %%
np.set_printoptions(precision=3, suppress=True, linewidth=200)

# %%
#r = alpha*dt/(dx**2)
r = 0.500

# %%
N = 50
T = np.full(N, 20.)
T[0]=40.
T[-1]=100.
idx = np.arange(N)
fig = make_subplots()
fig.add_scatter(x=idx, y=T, mode='lines', name='t=0')
for n in range(5000):
    T[1:-1] = T[1:-1] + r*(T[2:] -2*T[1:-1] + T[:-2])
    if n % 50 == 0:
        fig.add_scatter(x=idx, y=T, mode='lines', name=f't={n+1}')
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
