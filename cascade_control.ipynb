# %% [markdown]
# <a href="https://colab.research.google.com/github/chetools/CHE4071_Spring2026/blob/main/cascade_control.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -N -q https://raw.githubusercontent.com/chetools/chetools/main/tools/che5.ipynb -O che5.ipynb
# %run che5.ipynb

# %%
Kc_slave = 2.
Kc_master = 1.
taui_master = 1e5

Gp_inner = 1.5/(2*s + 1)
Gc_slave = Kc_slave  #slave controller is almost always just a proportional controller
Gd_inner = 1/(2.5*s + 1)
Gp_outer = 1./(20*s + 1)
Gc_master = Kc_master *(1 + 1/(taui_master*s))
